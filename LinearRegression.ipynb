# %%
#step 1 for LR daaset load krna
import pandas as pd
data={'Experience':[1,2,3,4,5],
      "Salary":[3000,3500,4000,4500,5000]}

df=pd.DataFrame(data)
df
# Out:
#    Experience  Salary
# 0           1    3000
# 1           2    3500
# 2           3    4000
# 3           4    4500
# 4           5    5000

# %%
#step2 data visualization k linear ya sort of linear hai?
import matplotlib.pyplot as plt
plt.scatter(df['Experience'],df['Salary'])
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.show()

# %%
#step3 split into training and testing data
from sklearn.model_selection import train_test_split
X=df[['Experience']]  #q k data 2D mei cahhiye hota hai ye wo hai jis sy salary ko predict krna hai .(input feature)
y=df['Salary'] #again samjhna hai(taret variable hai ) iski just values chhaiye is lye 1D
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=43)

# %%
#step4 mwi model train krna hai
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#    Experience
# 3           4

# %%
y_test
# Out:
# 3    4500
# Name: Salary, dtype: int64

# %%
model.predict(X_test.iloc[[0]]) #ye sirf existing data k lye hota hai
 #error ayga q k predict ka func 2D data expect krta hai
# Out:
# array([4500.])

# %%
model.predict(X_test) #for new data ye prididctions krta ha i
model.predict([[6]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5500.])

# %%
new_experience = pd.DataFrame({'Experience': [7, 8, 9]})
predictions = model.predict(new_experience)
print(predictions)
# Out:
# [6000. 6500. 7000.]

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Experience'],df['Salary'],color='blue',label='Training data')
plt.plot(df["Experience"],model.predict(X),color='green',label='Model Line')
plt.scatter(new_experience,predictions,color='red',label='New Data')

plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.legend()
plt.grid(True)
plt.show()

# %%
m=model.coef_
c=model.intercept_
print(m,c)
# Out:
# [500.] 2500.0

# %%
m*8+c
# Out:
# array([6500.])

# %%
# 1. Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 2. Data
data = {
    'Study_Hours': [1, 2, 3, 4, 5],
    'Exam_Score': [50, 55, 65, 70, 75]
}
df = pd.DataFrame(data)

# 3. Visualize
plt.scatter(df['Study_Hours'], df['Exam_Score'])
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Study Hours vs Score")
plt.show()

# 4. Split
X = df[['Study_Hours']]
y = df['Exam_Score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# 5. Train Model
model = LinearRegression()
model.fit(X_train, y_train)

# 6. Model Parameters
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)

# 7. Predict
predictions = model.predict(X_test)
print("Predicted Score:", predictions)

# Predict for 6 hours
score_for_6_hours = model.predict([[6]])
print("Predicted score for 6 study hours:", score_for_6_hours[0])

# 8. Evaluate
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)
print("MSE:", mse)
print("R² Score:", r2)

# 9. Plot line
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Best Fit Line")
plt.show()
# Out:
# Slope (m): 6.5
# Intercept (c): 43.0
# Predicted Score: [62.5]
# Predicted score for 6 study hours: 82.0
# MSE: 6.25
# R² Score: nan
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
